# %%
import pandas as pd
import numpy as np
import matplotlib 
df = pd.read_csv(r'/Users/calyamp/Downloads/1625247454.3564217.CSV',encoding='latin-1')

# %%
df
# Out:
#                User Name  Driver Id  Policy Number      D.O.P  Block Id  \
# 0          James Stanley    4308341        9498470   3/3/2020     28254
# 1       Paul Brandenburg    3277845        9981126  6/19/2020     43452
# 2          Wilma Rodgers    2592850        5301267   4/7/2020     69887
# 3           Rhonda Jones    6937168        4294524  10/1/2020     55092
# 4              John Mayo    4308616        8584296   4/4/2020     13330
# ...                  ...        ...            ...        ...       ...
# 81299       Diane Joiner    2539231        9803605   7/3/2020     64541
# 81300       Geneva Beard    7597027        3792630   7/3/2020     20035
# 81301      Carole Garcia    1683676        5957932   9/3/2020     52249
# 81302  Elizabeth Herrera    3393152        1773937  12/9/2020     27938
# 81303       Robert Davis    8326057        8682785   7/1/2020     39759
#
#                            Location                  Issue       D.O.I  \
# 0                      McKenzie, AL            Hit and Run  05/19/2021
# 1      Otis Orchards-East Farms, WA            Hit and Run  05/26/2021
# 2                     Fifty-Six, AR    Bike & Car Accident  12/03/2020
# 3                         Cidra, PR            Hit and Run  01/25/2021
# 4                    Vintondale, PA            Hit and Run  01/24/2021
# ...                             ...                    ...         ...
# 81299              East Prairie, MO             Auto Theft  11/10/2020
# 81300                 Snowflake, AZ    Single Car Accident  03/10/2021
# 81301                  Millport, AL  Multiple Car Accident  03/23/2021
# 81302                   Ozawkie, KS    Bike & Car Accident  05/13/2021
# 81303           Miramiguoa Park, MO  Multiple Car Accident  12/19/2020
#
#             D.O.R  Amount  Asset  Sybil Attack  Claim Id  Age
# 0      06/22/2021    2578  20626             1   9776250   40
# 1      05/28/2021   12622   5169             0   3301936   54
# 2      06/03/2021   15577   5234             0   7280014   58
# 3      03/17/2021   19605  26827             0   5169910   55
# 4      02/14/2021   12961  49696             0   9167296   55
# ...           ...     ...    ...           ...       ...  ...
# 81299  03/27/2021    9948  36522             0   4484900   39
# 81300  06/19/2021   12909  52060             0   9268155   32
# 81301  06/20/2021    3535  34720             0   8672841   17
# 81302  06/15/2021   15004  16123             0   4128732   53
# 81303  02/06/2021    7986   6348             0   6744426   39
#
# [81304 rows x 14 columns]

# %%
X = df.drop(['Sybil Attack'], axis=1)

# %%
X
# Out:
#                User Name  Driver Id  Policy Number      D.O.P  Block Id  \
# 0          James Stanley    4308341        9498470   3/3/2020     28254
# 1       Paul Brandenburg    3277845        9981126  6/19/2020     43452
# 2          Wilma Rodgers    2592850        5301267   4/7/2020     69887
# 3           Rhonda Jones    6937168        4294524  10/1/2020     55092
# 4              John Mayo    4308616        8584296   4/4/2020     13330
# ...                  ...        ...            ...        ...       ...
# 81299       Diane Joiner    2539231        9803605   7/3/2020     64541
# 81300       Geneva Beard    7597027        3792630   7/3/2020     20035
# 81301      Carole Garcia    1683676        5957932   9/3/2020     52249
# 81302  Elizabeth Herrera    3393152        1773937  12/9/2020     27938
# 81303       Robert Davis    8326057        8682785   7/1/2020     39759
#
#                            Location                  Issue       D.O.I  \
# 0                      McKenzie, AL            Hit and Run  05/19/2021
# 1      Otis Orchards-East Farms, WA            Hit and Run  05/26/2021
# 2                     Fifty-Six, AR    Bike & Car Accident  12/03/2020
# 3                         Cidra, PR            Hit and Run  01/25/2021
# 4                    Vintondale, PA            Hit and Run  01/24/2021
# ...                             ...                    ...         ...
# 81299              East Prairie, MO             Auto Theft  11/10/2020
# 81300                 Snowflake, AZ    Single Car Accident  03/10/2021
# 81301                  Millport, AL  Multiple Car Accident  03/23/2021
# 81302                   Ozawkie, KS    Bike & Car Accident  05/13/2021
# 81303           Miramiguoa Park, MO  Multiple Car Accident  12/19/2020
#
#             D.O.R  Amount  Asset  Claim Id  Age
# 0      06/22/2021    2578  20626   9776250   40
# 1      05/28/2021   12622   5169   3301936   54
# 2      06/03/2021   15577   5234   7280014   58
# 3      03/17/2021   19605  26827   5169910   55
# 4      02/14/2021   12961  49696   9167296   55
# ...           ...     ...    ...       ...  ...
# 81299  03/27/2021    9948  36522   4484900   39
# 81300  06/19/2021   12909  52060   9268155   32
# 81301  06/20/2021    3535  34720   8672841   17
# 81302  06/15/2021   15004  16123   4128732   53
# 81303  02/06/2021    7986   6348   6744426   39
#
# [81304 rows x 13 columns]

# %%
Y = df.iloc[:,11]

# %%
Y
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 81299    0
# 81300    0
# 81301    0
# 81302    0
# 81303    0
# Name: Sybil Attack, Length: 81304, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X = X.apply(LabelEncoder().fit_transform)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, train_size=0.7, random_state = 42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (56912, 13)
# (24392, 13)
# (56912,)
# (24392,)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 100, criterion = "entropy")
rfc.fit(X_train, Y_train) 
  
#Predict the value for new, unseen data
Y_pred = rfc.predict(X_test)
Y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
# %%time
accuracy = rfc.score(X_test, Y_test)
print("Accuracy is:", accuracy)
# Out:
# Accuracy is: 0.7922269596589046
# CPU times: user 480 ms, sys: 2.14 ms, total: 482 ms
# Wall time: 481 ms

# %%
# %%time
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(Y_test,Y_pred))
print(classification_report(Y_test,Y_pred))
# Out:
# [[19321   111]
#  [ 4957     3]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.99      0.88     19432
#            1       0.03      0.00      0.00      4960
#
#     accuracy                           0.79     24392
#    macro avg       0.41      0.50      0.44     24392
# weighted avg       0.64      0.79      0.70     24392
#
# CPU times: user 39.7 ms, sys: 2.22 ms, total: 41.9 ms
# Wall time: 40.3 ms

# %%
# %%time
import matplotlib.pyplot as plt
# for plotting the graph inside the notebook itself
# %matplotlib inline

plt.plot(X, Y)
plt.xlabel('Time')
plt.ylabel('Packets')
# Out:
# CPU times: user 254 ms, sys: 60.7 ms, total: 315 ms
# Wall time: 1.35 s
# Text(0, 0.5, 'Packets')

# %%
# %%time
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(Y_test,Y_pred))
print(classification_report(Y_test,Y_pred))
# Out:
# [[19321   111]
#  [ 4957     3]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.99      0.88     19432
#            1       0.03      0.00      0.00      4960
#
#     accuracy                           0.79     24392
#    macro avg       0.41      0.50      0.44     24392
# weighted avg       0.64      0.79      0.70     24392
#
# CPU times: user 46 ms, sys: 2.52 ms, total: 48.6 ms
# Wall time: 47.1 ms
